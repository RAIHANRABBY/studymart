# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import scipy as sp
import seaborn as sns
# %matplotlib inline

# %%
CD=pd.read_csv('data/covid_19_data.csv')
CD.head()
# Out:
#    SNo ObservationDate Province/State  Country/Region      Last Update  \
# 0    1      01/22/2020          Anhui  Mainland China  1/22/2020 17:00
# 1    2      01/22/2020        Beijing  Mainland China  1/22/2020 17:00
# 2    3      01/22/2020      Chongqing  Mainland China  1/22/2020 17:00
# 3    4      01/22/2020         Fujian  Mainland China  1/22/2020 17:00
# 4    5      01/22/2020          Gansu  Mainland China  1/22/2020 17:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# 4        0.0     0.0        0.0

# %%
CD.shape
# Out:
# (306429, 8)

# %%
CD.isnull().sum()
# Out:
# SNo                    0
# ObservationDate        0
# Province/State     78100
# Country/Region         0
# Last Update            0
# Confirmed              0
# Deaths                 0
# Recovered              0
# dtype: int64

# %%
CD.loc[CD['Country/Region']=='Mainland China','Province/State'].isnull().any()
# Out:
# False

# %%
TCV=pd.read_csv('data/time_series_covid_19_confirmed.csv')
TCV.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  5/20/21  5/21/21  5/22/21  \
# 0        0        0        0        0  ...    64575    65080    65486
# 1        0        0        0        0  ...   132118   132153   132176
# 2        0        0        0        0  ...   126156   126434   126651
# 3        0        0        0        0  ...    13569    13569    13569
# 4        0        0        0        0  ...    31661    31909    32149
#
#    5/23/21  5/24/21  5/25/21  5/26/21  5/27/21  5/28/21  5/29/21
# ...

# %%
TCVUS=pd.read_csv('data/time_series_covid_19_confirmed_US.csv')
TCVUS.head()
# Out:
#         UID iso2 iso3  code3    FIPS   Admin2 Province_State Country_Region  \
# 0  84001001   US  USA    840  1001.0  Autauga        Alabama             US
# 1  84001003   US  USA    840  1003.0  Baldwin        Alabama             US
# 2  84001005   US  USA    840  1005.0  Barbour        Alabama             US
# 3  84001007   US  USA    840  1007.0     Bibb        Alabama             US
# 4  84001009   US  USA    840  1009.0   Blount        Alabama             US
#
#          Lat      Long_  ... 5/20/21  5/21/21  5/22/21  5/23/21  5/24/21  \
# 0  32.539527 -86.644082  ...    7049     7106     7113     7118     7118
# 1  30.727750 -87.722071  ...   21489    21511    21535    21546    21554
# 2  31.868263 -85.387129  ...    2326     2327     2328     2328     2328
# 3  32.996421 -87.125115  ...    2656     2657     2656     2658     2659
# 4  33.982109 -86.567906  ...    6816     6826     6829     6832     6832
#
#    5/25/21  5/26/21  5/27/21  5/28/21  5/29/21
# ...

# %%
TD=pd.read_csv('data/time_series_covid_19_deaths.csv')
TD.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  5/20/21  5/21/21  5/22/21  \
# 0        0        0        0        0  ...     2772     2782     2792
# 1        0        0        0        0  ...     2440     2441     2442
# 2        0        0        0        0  ...     3401     3405     3411
# 3        0        0        0        0  ...      127      127      127
# 4        0        0        0        0  ...      704      709      715
#
#    5/23/21  5/24/21  5/25/21  5/26/21  5/27/21  5/28/21  5/29/21
# ...

# %%
TDUS=pd.read_csv('data/time_series_covid_19_deaths_US.csv')
TDUS.head()
# Out:
#         UID iso2 iso3  code3    FIPS   Admin2 Province_State Country_Region  \
# 0  84001001   US  USA    840  1001.0  Autauga        Alabama             US
# 1  84001003   US  USA    840  1003.0  Baldwin        Alabama             US
# 2  84001005   US  USA    840  1005.0  Barbour        Alabama             US
# 3  84001007   US  USA    840  1007.0     Bibb        Alabama             US
# 4  84001009   US  USA    840  1009.0   Blount        Alabama             US
#
#          Lat      Long_  ... 5/20/21  5/21/21  5/22/21  5/23/21  5/24/21  \
# 0  32.539527 -86.644082  ...     109      109      110      110      110
# 1  30.727750 -87.722071  ...     310      310      310      310      310
# 2  31.868263 -85.387129  ...      58       58       58       58       58
# 3  32.996421 -87.125115  ...      64       64       64       64       64
# 4  33.982109 -86.567906  ...     139      139      139      139      139
#
#    5/25/21  5/26/21  5/27/21  5/28/21  5/29/21
# ...

# %%
TR=pd.read_csv('data/time_series_covid_19_recovered.csv')
TR.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  5/20/21  5/21/21  5/22/21  \
# 0        0        0        0        0  ...    55687    55790    55889
# 1        0        0        0        0  ...   127869   128425   128601
# 2        0        0        0        0  ...    87902    88066    88208
# 3        0        0        0        0  ...    13234    13234    13234
# 4        0        0        0        0  ...    26483    26513    26775
#
#    5/23/21  5/24/21  5/25/21  5/26/21  5/27/21  5/28/21  5/29/21
# ...

# %%
TR.shape
# Out:
# (261, 498)
